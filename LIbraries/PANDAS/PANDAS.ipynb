# %% [markdown]
# ## what is pandas
# - Pandas is a python libraru used for data manipulation, analysis, cleaning and preparation
#
# # with pandas we can Read csv file

# %%
# build around dataframe (2D labeled table structure)

# 1. data frame :- table - like structure with rows and columns , support SQL like indexing

# filter slicing .

# 2. data cleaning - handle missing values(NaN0), du;licates, dtype conversion via dropna(),fillna(),astype()

# 3. GrpupBy ans aggregation = group by(), pivot_table for last affr(sum /mean/ countby)

# 4. ecosystem integration:-  works well with numpy , matplotlib, scikitlearn,sql core ds pipeline

# %% [markdown]
# - A DataFrame is a 2-dimensional data structure that can store data of different types (including characters, integers, floating point values, categorical data and more) in columns
#
# -  It is similar to a spreadsheet, a SQL table or the data.frame in R.
#
# - Each column in dataframe is a series

# %%
# Dataframe fundamentals
import pandas as pd
data={
    'name':['Alice','Bob','Claire'],
    'Age':[25,24,23],
    'Gender':['Female','Male','Female'],
    'city':['New York','San Francisco','Los Angeles']
}

# %%
df=pd.DataFrame(data)
df
# Out:
#      name  Age  Gender           city
# 0   Alice   25  Female       New York
# 1     Bob   24    Male  San Francisco
# 2  Claire   23  Female    Los Angeles

# %%
# to view basics info of dataset till 5th row

df.head()

df.tail()  # d
# Out:
#      name  Age  Gender           city
# 0   Alice   25  Female       New York
# 1     Bob   24    Male  San Francisco
# 2  Claire   23  Female    Los Angeles

# %%
#  To view the size of the dataset
df.shape
# Out:
# (3, 4)

# %%
# to understand the type of the data

df.dtypes
# Out:
# name      object
# Age        int64
# Gender    object
# city      object
# dtype: object

# %%
# tells everything about out dataset


df.info
# Out:
# <bound method DataFrame.info of      name  Age  Gender           city
# 0   Alice   25  Female       New York
# 1     Bob   24    Male  San Francisco
# 2  Claire   23  Female    Los Angeles>

# %%
# select rows and columns

print(df['name'])  # selecting rows only
print(df[['Age','city']]) # selecting two rows
# Out:
# 0     Alice
# 1       Bob
# 2    Claire
# Name: name, dtype: object
#    Age           city
# 0   25       New York
# 1   24  San Francisco
# 2   23    Los Angeles

# %%
# first row by position

print(df.iloc[0])
# Out:
# name         Alice
# Age             25
# Gender      Female
# city      New York
# Name: 0, dtype: object

# %%
# first roe by label

print(df.loc[0])
# Out:
# name         Alice
# Age             25
# Gender      Female
# city      New York
# Name: 0, dtype: object

# %%
# checking data with condition

df[df['Age']>23]
# Out:
#     name  Age  Gender           city
# 0  Alice   25  Female       New York
# 1    Bob   24    Male  San Francisco

# %%
# changing trhe value

# %%
# addig new column and increasing age

df['age_after_5_years']=df['Age']+5
display(df)
# Out:
#      name  Age  Gender           city  age_after_5_years
# 0   Alice   25  Female       New York                 30
# 1     Bob   24    Male  San Francisco                 29
# 2  Claire   23  Female    Los Angeles                 28

# %%
# adding new column changing nee city
df['New_country'] = ['India','brazil','france']
display(df)
# Out:
#      name  Age  Gender           city  age_after_5_years New_country
# 0   Alice   25  Female       New York                 30       India
# 1     Bob   24    Male  San Francisco                 29      brazil
# 2  Claire   23  Female    Los Angeles                 28      france

# %%
# converting all the upper case into lower

df.apply(lambda col:col.str.lower() if col.dtype=='object' else col)
# Out:
#      name  Age  Gender           city  age_after_5_years
# 0   alice   25  female       new york                 30
# 1     bob   24    male  san francisco                 29
# 2  claire   23  female    los angeles                 28

# %%
df['marks']=0

df.loc[2,'marks']=10

# .at  - fast for a single value

df.at[1,'city']='mumbai'
df

# using .iloc by row and column position

df.iloc[2,df.columns.get_loc('marks')]=90

df
# Out:
#      name  Age  Gender         city  age_after_5_years New_country  marks
# 0   Alice   25  Female     New York                 30       India      0
# 1     Bob   24    Male       mumbai                 29      brazil      0
# 2  Claire   23  Female  Los Angeles                 28      france     90

# %%
# changing multiple values using for loop
for i in df.index:
  if df.loc[i,'marks']==0:
    df.loc[i,'marks']=90

# %%
df
# Out:
#      name  Age  Gender         city  age_after_5_years New_country  marks
# 0   Alice   25  Female     New York                 30       India     90
# 1     Bob   24    Male       mumbai                 29      brazil     90
# 2  Claire   23  Female  Los Angeles                 28      france     90

# %%
# doing same thing using pandas

df.loc[df['marks']==90,'marks']=80
df
# Out:
#      name  Age  Gender         city  age_after_5_years New_country  marks
# 0   Alice   25  Female     New York                 30       India     80
# 1     Bob   24    Male       mumbai                 29      brazil     80
# 2  Claire   23  Female  Los Angeles                 28      france     80

# %%
# another simple way
df['marks']=df['marks'].replace(80,100)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1190/1751115445.py in <cell line: 0>()
#       1 # another simple way
# ----> 2 df['marks']=df['marks'].replace(80,100)
#       3 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Readung a dataset and performing operations

# %%
# imprtting dataset
import pandas as pd
data="/content/index_1.csv"
df=pd.read_csv(data,index_col=0)

#df.head()
print(df.tail())   # ti read last data
# Out:
#                            datetime cash_type                 card  money  \
# date
# 2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158  35.76
# 2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315  35.76
# 2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315  35.76
# 2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316  25.96
# 2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275  35.76
#
#            coffee_name
# date
# 2025-03-23  Cappuccino
# 2025-03-23       Cocoa
# 2025-03-23       Cocoa
# 2025-03-23   Americano
# 2025-03-23       Latte

# %%
df.shape
# Out:
# (3636, 5)

# %%
# checking for null value

print(df.isnull())   # will show if there is any null value
# Out:
#             datetime  cash_type   card  money  coffee_name
# date
# 2024-03-01     False      False  False  False        False
# 2024-03-01     False      False  False  False        False
# 2024-03-01     False      False  False  False        False
# 2024-03-01     False      False  False  False        False
# 2024-03-01     False      False  False  False        False
# ...              ...        ...    ...    ...          ...
# 2025-03-23     False      False  False  False        False
# 2025-03-23     False      False  False  False        False
# 2025-03-23     False      False  False  False        False
# 2025-03-23     False      False  False  False        False
# 2025-03-23     False      False  False  False        False
#
# [3636 rows x 5 columns]

# %%
print(df.isnull().any())   # this will return true false
# Out:
# datetime       False
# cash_type      False
# card            True
# money          False
# coffee_name    False
# dtype: bool

# %%
print(df.isnull().sum())   # will give the sum of null values form each  of the null values
# Out:
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %% [markdown]
# ## checkig for before and after drop

# %%
print("beofre drop",df.shape)
# Out:
# beofre drop (3636, 5)

# %% [markdown]
# ## By default dropna() method returns  a new dataframe and will not change the original.

# %%
print("after drop shape",df.dropna().shape)
# Out:
# after drop shape (3547, 5)

# %% [markdown]
# # Inplace _ if want to change the original dataframe , use inplace =True argument.

# %%
df.dropna(inplace=True) #Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.
print(df.isnull().sum())
# Out:
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# dtype: int64

# %% [markdown]
# # Repalce empty value:-
# - Another way to deal with empty or null value is to replace the value insted
#  - This way you do not have to delete entire row just because of a empty cell
#  - The fillna() method allow us to replace empty cell without value

# %%
df.fillna(0,inplace=True) # replace null value with 0

# %%
df.fillna(99,inplace=True)  # repalce null value with 99

# %% [markdown]
# # Replace only for specified column
# - To only replace the empty value from one column, specify the column name for the DataFrame.

# %%
df.fillna({"card":'Paid'},inplace=True)  # replacing null values with Paid

# %% [markdown]
# ## Replace Using Mean Median and Mode
# - This is a common way to fill the empty or null values
# - pandas uses mean() , median(), and mode() method to calculate the prespective values fro a specified column

# %%
df.head()
# Out:
#                            datetime cash_type                 card  money  \
# date
# 2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#               coffee_name
# date
# 2024-03-01          Latte
# 2024-03-01  Hot Chocolate
# 2024-03-01  Hot Chocolate
# 2024-03-01      Americano
# 2024-03-01          Latte

# %%
x=df['money'].mean()  # calculating mean of money column

# %% [markdown]
# # calculating mean of money columns and replacing if number is empty

# %%
df.fillna({'money':x},inplace=True)

# %% [markdown]
# ## same for median and mode

# %%
y=df['money'].median()  # calculating median of money column

# %%
df.fillna({'money':y},inplace=True)

# %% [markdown]
# # same for mode

# %%
z=df['card'].mode()

# %%
df.fillna({'card':x},inplace=True)

# %% [markdown]
# ## = DATA OF Wrong formate
#
# - Cells with wrong data can make it difficult or even impossible to analyze data.
# - To fix we have two options:-
#     - Either remove the data
#     - convert all cells/rows of the column in the same formate.

# %%
df.tail()
# Out:
#                            datetime cash_type                 card  money  \
# date
# 2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158  35.76
# 2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315  35.76
# 2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315  35.76
# 2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316  25.96
# 2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275  35.76
#
#            coffee_name
# date
# 2025-03-23  Cappuccino
# 2025-03-23       Cocoa
# 2025-03-23       Cocoa
# 2025-03-23   Americano
# 2025-03-23       Latte

# %%
df['datetime']=pd.to_datetime(df['datetime'],format='mixed')  # convert to date

# %% [markdown]
# ## if the valyes were was as NULL or in string the value the conversion will return NaT- Not a number insted of NAN
# ## in other words empty value . one way to deal with simply remove the entire row .

# %%
# we can remove the row using dropna() method

df.dropna(subset=['datetime'], inplace=True)

# %% [markdown]
# ## Wrong DATA :-
#   - wrong data does not have to be empty cell or wrong format,
#   - It can just be wrong like, someone registered 199 insed of 1.99
#   - One way to fix the wrong values by replacing the values with something else.

# %%
# becaus herre no index given so this wont work here insted it will add a new row because it is not able to find the row

df.loc[4,['money']]=90
df
# Out:
#                           datetime cash_type                 card  money  \
# date
# 2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001  38.70
# 2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002  38.70
# 2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002  38.70
# 2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003  28.90
# 2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004  38.70
# ...                            ...       ...                  ...    ...
# 2025-03-23 2025-03-23 14:43:37.362      card  ANON-0000-0000-1315  35.76
# 2025-03-23 2025-03-23 14:44:16.864      card  ANON-0000-0000-1315  35.76
# 2025-03-23 2025-03-23 15:47:28.723      card  ANON-0000-0000-1316  25.96
# 2025-03-23 2025-03-23 18:11:38.635      card  ANON-0000-0000-1275  35.76
# 4                              NaT     Paise                  NaN  90.00
#
#               coffee_name
# date
# 2024-03-01          Latte
# ...

# %%
# this is what we have to do insted

df.iloc[4,df.columns.get_loc('cash_type')]='Paise'

# now using ioc and this function we can simply modify the needed if the idex is not specified in the column

df
# Out:
#                           datetime cash_type                 card  money  \
# date
# 2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001  38.70
# 2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002  38.70
# 2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002  38.70
# 2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003  28.90
# 2024-03-01 2024-03-01 13:48:14.626     Paise  ANON-0000-0000-0004  38.70
# ...                            ...       ...                  ...    ...
# 2025-03-23 2025-03-23 14:43:37.362      card  ANON-0000-0000-1315  35.76
# 2025-03-23 2025-03-23 14:44:16.864      card  ANON-0000-0000-1315  35.76
# 2025-03-23 2025-03-23 15:47:28.723      card  ANON-0000-0000-1316  25.96
# 2025-03-23 2025-03-23 18:11:38.635      card  ANON-0000-0000-1275  35.76
# 4                              NaT     Paise                  NaN  90.00
#
#               coffee_name
# date
# 2024-03-01          Latte
# ...

# %% [markdown]
# ## if we have to work with big data set and replace any by value using for loop

# %%
df.loc[df['money'] > 30, 'money'] = 98
df.loc[df['money'] == 98, 'cash_type'] = 'paid'
df
# Out:
#                           datetime cash_type                 card  money  \
# date
# 2024-03-01 2024-03-01 10:15:50.520      paid  ANON-0000-0000-0001  98.00
# 2024-03-01 2024-03-01 12:19:22.539      paid  ANON-0000-0000-0002  98.00
# 2024-03-01 2024-03-01 12:20:18.089      paid  ANON-0000-0000-0002  98.00
# 2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003  28.90
# 2024-03-01 2024-03-01 13:48:14.626      paid  ANON-0000-0000-0004  98.00
# ...                            ...       ...                  ...    ...
# 2025-03-23 2025-03-23 14:43:37.362      paid  ANON-0000-0000-1315  98.00
# 2025-03-23 2025-03-23 14:44:16.864      paid  ANON-0000-0000-1315  98.00
# 2025-03-23 2025-03-23 15:47:28.723      card  ANON-0000-0000-1316  25.96
# 2025-03-23 2025-03-23 18:11:38.635      paid  ANON-0000-0000-1275  98.00
# 4                              NaT      paid                  NaN  98.00
#
#               coffee_name
# date
# 2024-03-01          Latte
# ...

# %% [markdown]
# ## Another way to handling wrong data is do remove the row that contain wrong data
# - This way you dont have to find out what to replace them with

# %%
for i in df.index:
  if df.loc[i,'money']==98:
    df.dropna(i,inplace=True)

    # this is how we can remove the wrong value in big dataset

# %% [markdown]
# ## Duplicate row means the row are registered more then one time
# - To discover duplicate we can use duplicated() method.
# - it return boolean value for each row
# - return True for every row that is duplicated, otherwise False

# %%
df.duplicated()
# Out:
# date
# 2024-03-01    False
# 2024-03-01    False
# 2024-03-01    False
# 2024-03-01    False
# 2024-03-01    False
#               ...
# 2025-03-23    False
# 2025-03-23    False
# 2025-03-23    False
# 2025-03-23    False
# 4             False
# Length: 3548, dtype: bool

# %% [markdown]
# # To remove duplicaes we can simply use __ drop_duplicates() method

# %%
df.drop_duplicates(inplace=True) # this is how we can remove duplicate rows

# %% [markdown]
# ## always remember inplace true , makes sure that the method does not return any new dataframe it modifies the same dataframe

# %% [markdown]
# ## PANDAS DATA **CORRELATIONS**

# %%
data_df=pd.read_csv("/content/data.csv")
data_df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# # The **corr()** method calculates the relationship between each column in our dataset.
# - The corr() ignores "not numeric" columns

# %%
data_df.corr() # corr() wil shoe correlation in data
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# ##Result Explained
# The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
#
# ---
#
#
#
# The number varies from -1 to 1.
#
#   - 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
#   - 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
#   - -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
#   - 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

# %% [markdown]
# ## What is a good correlation ?
# - It depends on the use
# - it is safe to say if we have at leans 0.6 or - 0.6 to call it a good correlation

# %% [markdown]
# # what is a prefectm correlation ?
# - Each column has perfect relationshiop with itself
# - whihc is 1.00000

# %% [markdown]
# # What is a good correlation ?
# - 0.9 is very good correlation because it predict the longer you work more will go down

# %% [markdown]
# # very bad correlation :-
#  - 0.0009 is very bad
#  - means you can not predict any by lookig to other

# %% [markdown]
# ## PADAS uses plot method to create  diagrams
# - we can ise pyplot submodule of matplotlib library to visualize the diagram on the screen

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("/content/data.csv")

# %%
# generating plot for it
data.plot()
plt.show()

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# ## To create diffrent plot using pandas
# - We have to define first which type of plot we want

# %% [markdown]
# ## Scatter plot:-
#  - Have to specify that we want scatter plot  with the **kind** argument
#         - kind='scatter'
#  - A scatter plot need x and y - axis
#  - Include x and y argument like this

# %% [markdown]
# ## correlation between "Duration" and "Calories" was
# - 0.922721, and we concluded with the fact that higher duration means more calories burned.

# %%
data.plot(kind='scatter',x='Duration', y='Calories')  # x -axis is duration , y-axis is calories
plt.show()

# %% [markdown]
# ## Let's create another scatterplot, where there is a bad relationship between the columns, like
# - "Duration" and "Maxpulse", with the correlation 0.009403:

# %%
data.plot(kind='scatter',x='Duration',y='Maxpulse') # now x axis is calories and y axis in maxpulse
# Out:
# <Axes: xlabel='Duration', ylabel='Maxpulse'>

# %% [markdown]
# #### Histogram - USe king argument to specify that you want histogram
# - # Kind= 'hist'
# - this needs only one column
# - it show a frequency of each interval

# %%
# Duration column to create histogram
data['Duration'].plot(kind='hist')
plt.show()

# %%
data['Calories'].plot(kind='hist')
plt.show()
