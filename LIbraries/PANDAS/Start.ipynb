# %% [markdown]
# ## What is PANDAS
#
# - Pandas is open source library use for worling with dataset for data manipulation and analysis.
#
# - It has function for analyzing, cleaning, exploring and manipulation data.
#
# - It is build on the top of NUMPY and provides powerful tools to work with structured data like tables (row and columns )
#
# - Think of pandas a Excel for python - but faster , more reliable, and much more powerful
#
#
# -  Pandas reger to both "Panel Data" and Python data analysis
