# %% [markdown]
# ## creating numpy array using buildin function

# %% [markdown]
# # arrange and linespace

# %%
import numpy as np

# %%
# range (start,stop,step)
# np.arrange(start,stop,step,dtype)

list(range(1,10,2)) # using range only
# Out:
# [1, 3, 5, 7, 9]

# %%
# np.arrange

np.arange(1,50,5,dtype=np.float128)

# 1 byte = 8 bit
# f is short form of np.float32 = 4 bytes
# float is used in python  usually 64 bit 
# float64 means 8 bytes
# Out:
# array([ 1.,  6., 11., 16., 21., 26., 31., 36., 41., 46.])

# %%
# Out:
# ['hritik', 1, 'hritik', 2, 'ravi', 3, 'akahs', 4]
